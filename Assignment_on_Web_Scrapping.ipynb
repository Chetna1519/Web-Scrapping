# %% [markdown]
# <a href="https://colab.research.google.com/github/Chetna1519/Web-Scrapping/blob/main/Assignment_on_Web_Scrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url = "http://quotes.toscrape.com/page/1/"

# %%
response = requests.get(url)

# %%
response = response.content
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-265643f1204f> in <cell line: 1>()
# ----> 1 response = response.content
#
# AttributeError: 'bytes' object has no attribute 'content'

# %%
soup = BeautifulSoup(response, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Quotes to Scrape</title>
# <link href="/static/bootstrap.min.css" rel="stylesheet"/>
# <link href="/static/main.css" rel="stylesheet"/>
# </head>
# <body>
# <div class="container">
# <div class="row header-box">
# <div class="col-md-8">
# <h1>
# <a href="/" style="text-decoration: none">Quotes to Scrape</a>
# </h1>
# </div>
# <div class="col-md-4">
# <p>
# <a href="/login">Login</a>
# </p>
# </div>
# </div>
# <div class="row">
# <div class="col-md-8">
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# <span>by <small class="author" itemprop="author">Albert Einstein</small>
# <a href="/author/Albert-Einstein">(about)</a>
# </span>
# <div class="tags">
#             Tags:
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Quotes to Scrape
#   </title>
#   <link href="/static/bootstrap.min.css" rel="stylesheet"/>
#   <link href="/static/main.css" rel="stylesheet"/>
#  </head>
#  <body>
#   <div class="container">
#    <div class="row header-box">
#     <div class="col-md-8">
#      <h1>
#       <a href="/" style="text-decoration: none">
#        Quotes to Scrape
#       </a>
#      </h1>
#     </div>
#     <div class="col-md-4">
#      <p>
#       <a href="/login">
#        Login
#       </a>
#      </p>
#     </div>
#    </div>
#    <div class="row">
#     <div class="col-md-8">
#      <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#       <span class="text" itemprop="text">
#        “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
#       </span>
#       <span>
#        by
# ...

# %%
Div = soup.find('div')

# %%
 Quotes = soup.find_all('div', class_ ='quote')


for quote in Quotes:
  text = quote.find('span', class_ ='text').text
  author =  quote.find('small', class_ ='author')
  tags = [tag.text for tag in quote.find_all('a', class_ = 'tag')]
  print('Quote:-', text)
  print('Author:-', author)
  print('Tags:-',','.join(tags))
  print()
# Out:
# Quote:- “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
# Author:- <small class="author" itemprop="author">Albert Einstein</small>
# Tags:- change,deep-thoughts,thinking,world
#
# Quote:- “It is our choices, Harry, that show what we truly are, far more than our abilities.”
# Author:- <small class="author" itemprop="author">J.K. Rowling</small>
# Tags:- abilities,choices
#
# Quote:- “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”
# Author:- <small class="author" itemprop="author">Albert Einstein</small>
# Tags:- inspirational,life,live,miracle,miracles
#
# Quote:- “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”
# Author:- <small class="author" itemprop="author">Jane Austen</small>
# Tags:- aliteracy,books,classic,humor
#
# ...

# %%
books = []

for i in range(1,11):
  url = "http://quotes.toscrape.com/page/1/"
  response = requests.get(url)
  response = response.content
  soup = BeautifulSoup(response, 'html.parser')
  Div = soup.find('div')
  Quotes = soup.find_all('div', class_ ='quote')

  for quote in Quotes:
    author =  quote.find('small', class_ ='author')
    text = quote.find('span', class_ ='text').text
    tags = [tag.text for tag in quote.find_all('a', class_ = 'tag')]
    books.append([author,text,tags])

# %%
df = pd.DataFrame(books, columns =['Author', 'Quotes', 'Tags'])

# %%
df
# Out:
#                  Author                                             Quotes  \
# 0     [Albert Einstein]  “The world as we have created it is a process ...
# 1        [J.K. Rowling]  “It is our choices, Harry, that show what we t...
# 2     [Albert Einstein]  “There are only two ways to live your life. On...
# 3         [Jane Austen]  “The person, be it gentleman or lady, who has ...
# 4      [Marilyn Monroe]  “Imperfection is beauty, madness is genius and...
# ..                  ...                                                ...
# 95    [Albert Einstein]  “Try not to become a man of success. Rather be...
# 96         [André Gide]  “It is better to be hated for what you are tha...
# 97   [Thomas A. Edison]  “I have not failed. I've just found 10,000 way...
# 98  [Eleanor Roosevelt]  “A woman is like a tea bag; you never know how...
# 99       [Steve Martin]  “A day without sunshine is like, you know, nig...
#
#                                               Tags
# ...

# %%
##Creating the CSV file to store the data
import csv
csv_filename = 'Quotes.csv'
with open(csv_filename, 'w', newline ='', encoding ='utf-8') as csvfile:
  writer = csv.writer(csvfile)
  writer.writerow(['Author', 'Quotes','Tags'])
  for quote in Quotes:
     author =  quote.find('small', class_ ='author')
     text = quote.find('span', class_ ='text').text
     tags = [tag.text for tag in quote.find_all('a', class_ = 'tag')]

     writer.writerow([author,text,','.join(tags)])

print(f'Data saved to csv_filename successfully.')
# Out:
# Data saved to csv_filename successfully.
